# %%
import pandas as pd 
df = pd.read_csv("train.csv")
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001000    Male      No        NaN      Graduate            No
# 1  LP001001  Female      No          0      Graduate            No
# 2  LP001002    Male     Yes         3+  Not Graduate            No
# 3  LP001003    Male     Yes          0      Graduate            No
# 4  LP001004    Male      No          0      Graduate           NaN
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             9019             2500.0          96             360.0
# 1             5695                0.0         230             360.0
# 2             6678             1500.0         113             360.0
# 3             4055             1500.0         295               NaN
# 4             3805             1500.0         293             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             0.0     Semiurban           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               5
# Dependents           14
# Education             0
# Self_Employed        43
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     12
# Credit_History       53
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    545
# N     69
# Name: count, dtype: int64
